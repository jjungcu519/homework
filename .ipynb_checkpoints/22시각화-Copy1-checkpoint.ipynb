# %% [markdown]
# # 0. 준비단계

# %%
# 라이브러리 호출
import os
import numpy as np
import pandas as pd
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
# 현재 작업 경로 확인
os.getcwd()
# Out:
# 'C:\\Users\\kim jeongah\\OneDrive\\Desktop\\DMF\\DBR_Project\\DBR_Project\\code'

# %%
# data 폴더로 작업 경로 변경
os.chdir(path = '../data')

# %%
# 현재 작업 경로에 있는 폴더명과 파일명 확인
os.listdir()
# Out:
# ['22_Prep.pkl',
#  'df22.pkl',
#  'df23.pkl',
#  'Naver_News_List.pkl',
#  'Naver_News_Reply.pkl',
#  'Text_Prep.pkl']

# %%
# pkl 파일을 읽고 corpus, tfs 및 dtm 생성
# [참고] pkl 파일로 저장할 때 지정한 파이썬 객체의 개수만큼 변수를 지정해야 함
corpus, tfs, dtm = pd.read_pickle(filepath_or_buffer = '22_Prep.pkl')

# %%
# 현재 사용 중인 컴퓨터에 설치한 전체 폰트 파일명을 리스트로 반환
fontList = fm.findSystemFonts(fontext = 'ttf')

# fontList 확인
fontList
# Out:
# ['C:\\Windows\\Fonts\\micross.ttf',
#  'C:\\Windows\\Fonts\\seguili.ttf',
#  'C:\\Windows\\Fonts\\Candaral.ttf',
#  'C:\\Windows\\Fonts\\malgun.ttf',
#  'C:\\Windows\\Fonts\\SegUIVar.ttf',
#  'C:\\Windows\\Fonts\\SitkaVF-Italic.ttf',
#  'C:\\Windows\\Fonts\\ariali.ttf',
#  'C:\\Windows\\Fonts\\Candarab.ttf',
#  'C:\\Windows\\Fonts\\seguibli.ttf',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'C:\\Windows\\Fonts\\verdanai.ttf',
#  'C:\\Windows\\Fonts\\corbeli.ttf',
#  'C:\\Windows\\Fonts\\mmrtextb.ttf',
#  'C:\\Windows\\Fonts\\comicz.ttf',
#  'C:\\Windows\\Fonts\\meiryob.ttc',
#  'C:\\Windows\\Fonts\\seguihis.ttf',
#  'C:\\Windows\\Fonts\\courbi.ttf',
#  'C:\\Windows\\Fonts\\ebrimabd.ttf',
#  'C:\\Windows\\Fonts\\malgunbd.ttf',
#  'C:\\Windows\\Fonts\\Gabriola.ttf',
#  'C:\\Windows\\Fonts\\seguisbi.ttf',
#  'C:\\Windows\\Fonts\\calibrib.ttf',
#  'C:\\Windows\\Fonts\\verdana.ttf',
#  'C:\\Windows\\Fonts\\l_10646.ttf',
#  'C:\\Windows\\Fonts\\mvboli.ttf',
#  'C:\\Windows\\Fonts\\trebuc.ttf',
#  'C:\\Windows\\Fonts\\gadugi.ttf',
#  'C:\\Windows\\Fonts\\consolab.ttf',
#  'C:\\Windows\\Fonts\\msgothic.ttc',
#  'C:\\Windows\\Fonts\\Candaraz.ttf',
#  'C:\\Windows\\Fonts\\trebucbi.ttf',
#  'C:\\Windows\\Fonts\\taile.ttf',
#  'C:\\Windows\\Fonts\\seguiemj.ttf',
#  'C:\\Windows\\Fonts\\BIZ-UDGothicB.ttc',
#  'C:\\Windows\\Fonts\\UDDigiKyokashoN-R.ttc',
#  'C:\\Windows\\Fonts\\YuGothB.ttc',
#  'C:\\Windows\\Fonts\\meiryo.ttc',
#  'C:\\Windows\\Fonts\\palabi.ttf',
#  'C:\\Windows\\Fonts\\georgiai.ttf',
#  'C:\\Windows\\Fonts\\malgunsl.ttf',
#  'C:\\Windows\\Fonts\\verdanab.ttf',
#  'C:\\Windows\\Fonts\\consola.ttf',
#  'C:\\Windows\\Fonts\\palab.ttf',
#  'C:\\Windows\\Fonts\\calibriz.ttf',
#  'C:\\Windows\\Fonts\\BIZ-UDGothicR.ttc',
#  'C:\\Windows\\Fonts\\segoeuii.ttf',
#  'C:\\Windows\\Fonts\\javatext.ttf',
#  'C:\\Windows\\Fonts\\corbelli.ttf',
#  'C:\\Windows\\Fonts\\msjhl.ttc',
#  'C:\\Windows\\Fonts\\georgiaz.ttf',
#  'C:\\Windows\\Fonts\\cambriaz.ttf',
#  'C:\\Windows\\Fonts\\constanb.ttf',
#  'C:\\Windows\\Fonts\\tahomabd.ttf',
#  'C:\\Windows\\Fonts\\UDDigiKyokashoN-B.ttc',
#  'C:\\Windows\\Fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\yumin.ttf',
#  'C:\\Windows\\Fonts\\calibrii.ttf',
#  'C:\\Windows\\Fonts\\corbelb.ttf',
#  'C:\\Windows\\Fonts\\timesbd.ttf',
#  'C:\\Windows\\Fonts\\seguisli.ttf',
#  'C:\\Windows\\Fonts\\webdings.ttf',
#  'C:\\Windows\\Fonts\\YuGothL.ttc',
#  'C:\\Windows\\Fonts\\NirmalaS.ttf',
#  'C:\\Windows\\Fonts\\comici.ttf',
#  'C:\\Windows\\Fonts\\arialbi.ttf',
#  'C:\\Windows\\Fonts\\LeelUIsl.ttf',
#  'C:\\Windows\\Fonts\\himalaya.ttf',
#  'C:\\Windows\\Fonts\\segmdl2.ttf',
#  'C:\\Windows\\Fonts\\palai.ttf',
#  'C:\\Windows\\Fonts\\consolai.ttf',
#  'C:\\Windows\\Fonts\\seguibl.ttf',
#  'C:\\Windows\\Fonts\\corbelz.ttf',
#  'C:\\Windows\\Fonts\\timesbi.ttf',
#  'C:\\Windows\\Fonts\\seguisym.ttf',
#  'C:\\Windows\\Fonts\\cour.ttf',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\Windows\\Fonts\\batang.ttc',
#  'C:\\Windows\\Fonts\\msjh.ttc',
#  'C:\\Windows\\Fonts\\YuGothM.ttc',
#  'C:\\Windows\\Fonts\\SansSerifCollection.ttf',
#  'C:\\Windows\\Fonts\\tahoma.ttf',
#  'C:\\Windows\\Fonts\\ebrima.ttf',
#  'C:\\Windows\\Fonts\\phagspa.ttf',
#  'C:\\Windows\\Fonts\\calibrili.ttf',
#  'C:\\Windows\\Fonts\\phagspab.ttf',
#  'C:\\Windows\\Fonts\\SegoeIcons.ttf',
#  'C:\\Windows\\Fonts\\symbol.ttf',
#  'C:\\Windows\\Fonts\\trebucbd.ttf',
#  'C:\\Windows\\Fonts\\georgiab.ttf',
#  'C:\\Windows\\Fonts\\ntailu.ttf',
#  'C:\\Windows\\Fonts\\constanz.ttf',
#  'C:\\Windows\\Fonts\\msyhl.ttc',
#  'C:\\Windows\\Fonts\\corbel.ttf',
#  'C:\\Windows\\Fonts\\SitkaVF.ttf',
#  'C:\\Windows\\Fonts\\ariblk.ttf',
#  'C:\\Windows\\Fonts\\pala.ttf',
#  'C:\\Windows\\Fonts\\comicbd.ttf',
#  'C:\\Windows\\Fonts\\Candarali.ttf',
#  'C:\\Windows\\Fonts\\BIZ-UDMinchoM.ttc',
#  'C:\\Windows\\Fonts\\segoeuiz.ttf',
#  'C:\\Windows\\Fonts\\msyi.ttf',
#  'C:\\Windows\\Fonts\\NirmalaB.ttf',
#  'C:\\Windows\\Fonts\\mingliub.ttc',
#  'C:\\Windows\\Fonts\\Inkfree.ttf',
#  'C:\\Windows\\Fonts\\corbell.ttf',
#  'C:\\Windows\\Fonts\\msjhbd.ttc',
#  'C:\\Windows\\Fonts\\monbaiti.ttf',
#  'C:\\Windows\\Fonts\\arialbd.ttf',
#  'C:\\Windows\\Fonts\\comic.ttf',
#  'C:\\Windows\\Fonts\\constan.ttf',
#  'C:\\Windows\\Fonts\\Candarai.ttf',
#  'C:\\Windows\\Fonts\\gadugib.ttf',
#  'C:\\Windows\\Fonts\\simsun.ttc',
#  'C:\\Windows\\Fonts\\holomdl2.ttf',
#  'C:\\Windows\\Fonts\\yumindb.ttf',
#  'C:\\Windows\\Fonts\\Nirmala.ttf',
#  'C:\\Windows\\Fonts\\segoeuisl.ttf',
#  'C:\\Windows\\Fonts\\lucon.ttf',
#  'C:\\Windows\\Fonts\\segoeuil.ttf',
#  'C:\\Windows\\Fonts\\msyh.ttc',
#  'C:\\Windows\\Fonts\\timesi.ttf',
#  'C:\\Windows\\Fonts\\sylfaen.ttf',
#  'C:\\Windows\\Fonts\\YuGothR.ttc',
#  'C:\\Windows\\Fonts\\segoeprb.ttf',
#  'C:\\Windows\\Fonts\\verdanaz.ttf',
#  'C:\\Windows\\Fonts\\msyhbd.ttc',
#  'C:\\Windows\\Fonts\\segoesc.ttf',
#  'C:\\Windows\\Fonts\\gulim.ttc',
#  'C:\\Windows\\Fonts\\segoeui.ttf',
#  'C:\\Windows\\Fonts\\wingding.ttf',
#  'C:\\Windows\\Fonts\\impact.ttf',
#  'C:\\Windows\\Fonts\\seguisb.ttf',
#  'C:\\Windows\\Fonts\\Candara.ttf',
#  'C:\\Windows\\Fonts\\arial.ttf',
#  'C:\\Windows\\Fonts\\LeelawUI.ttf',
#  'C:\\Windows\\Fonts\\cambriab.ttf',
#  'C:\\Windows\\Fonts\\calibri.ttf',
#  'C:\\Windows\\Fonts\\segoepr.ttf',
#  'C:\\Windows\\Fonts\\ntailub.ttf',
#  'C:\\Windows\\Fonts\\framd.ttf',
#  'C:\\Windows\\Fonts\\LeelaUIb.ttf',
#  'C:\\Windows\\Fonts\\cambriai.ttf',
#  'C:\\Windows\\Fonts\\yuminl.ttf',
#  'C:\\Windows\\Fonts\\framdit.ttf',
#  'C:\\Windows\\Fonts\\calibril.ttf',
#  'C:\\Windows\\Fonts\\courbd.ttf',
#  'C:\\Windows\\Fonts\\segoeuib.ttf',
#  'C:\\Windows\\Fonts\\bahnschrift.ttf',
#  'C:\\Windows\\Fonts\\trebucit.ttf',
#  'C:\\Windows\\Fonts\\msmincho.ttc',
#  'C:\\Windows\\Fonts\\couri.ttf',
#  'C:\\Windows\\Fonts\\mmrtext.ttf',
#  'C:\\Windows\\Fonts\\segoescb.ttf',
#  'C:\\Windows\\Fonts\\cambria.ttc',
#  'C:\\Windows\\Fonts\\constani.ttf',
#  'C:\\Windows\\Fonts\\taileb.ttf',
#  'C:\\Windows\\Fonts\\times.ttf']

# %%
# 리스트에서 특정 문자열(폰트명)을 포함하는 파일명 선택
fontPath = [font for font in fontList if 'batang' in font]

# fontPath 확인
fontPath
# Out:
# ['C:\\Windows\\Fonts\\batang.ttc']

# %%
# 반복문으로 컴퓨터에 설치한 폰트명 출력
for font in fontPath:
    print(fm.FontProperties(fname = font).get_name())
# Out:
# Batang

# %%
# 한글폰트와 글자 크기 설정
# [참고] 폰트를 설치하고 .matplotlib 폴더에서 fontlist-v3xx.json 파일을 삭제해야 함
plt.rc(group = 'font', family = 'Batang', size = 10)

# %%
# 그래프 크기와 해상도 설정
plt.rc(group = 'figure', figsize = (8, 4), dpi = 100)

# %% [markdown]
# # 1. 고빈도 단어 시각화

# %%
tfs_top10 = tfs.head(n = 10)
sns.barplot(x = tfs_top10.index, y = tfs_top10.values, color = 'silver')
plt.title(label = '고빈도 단어 목록(상위 10개)')
plt.xlabel(xlabel = '고빈도 단어')
plt.ylim(0, tfs_top10.max() * 1.2)
for i, v in enumerate(tfs_top10):
    plt.text(x = i, y = v, s = f'{v:.2f}', ha = 'center', va = 'bottom');

# %% [markdown]
# # 2. 워드 클라우드 시각화

# %%
freq = dict()

# %%
# 워드 클라우드 시각화용 딕셔너리 생성
# [참고] 키는 단어, 값은 단어의 도수임
for word in dtm.columns:
    freq[word] = dtm[word].sum()

# %%
# 컬러맵(팔레트) 목록 확인
# [참고] '_r'이 붙은 속성이 팔레트이며, '_r'은 reverse를 의미
dir(plt.cm)
# Out:
# ['Accent',
#  'Accent_r',
#  'Blues',
#  'Blues_r',
#  'BrBG',
#  'BrBG_r',
#  'BuGn',
#  'BuGn_r',
#  'BuPu',
#  'BuPu_r',
#  'CMRmap',
#  'CMRmap_r',
#  'ColormapRegistry',
#  'Dark2',
#  'Dark2_r',
#  'GnBu',
#  'GnBu_r',
#  'Grays',
#  'Greens',
#  'Greens_r',
#  'Greys',
#  'Greys_r',
#  'Mapping',
#  'OrRd',
#  'OrRd_r',
#  'Oranges',
#  'Oranges_r',
#  'PRGn',
#  'PRGn_r',
#  'Paired',
#  'Paired_r',
#  'Pastel1',
#  'Pastel1_r',
#  'Pastel2',
#  'Pastel2_r',
#  'PiYG',
#  'PiYG_r',
#  'PuBu',
#  'PuBuGn',
#  'PuBuGn_r',
#  'PuBu_r',
#  'PuOr',
#  'PuOr_r',
#  'PuRd',
#  'PuRd_r',
#  'Purples',
#  'Purples_r',
#  'RdBu',
#  'RdBu_r',
#  'RdGy',
#  'RdGy_r',
#  'RdPu',
#  'RdPu_r',
#  'RdYlBu',
#  'RdYlBu_r',
#  'RdYlGn',
#  'RdYlGn_r',
#  'Reds',
#  'Reds_r',
#  'ScalarMappable',
#  'Set1',
#  'Set1_r',
#  'Set2',
#  'Set2_r',
#  'Set3',
#  'Set3_r',
#  'Spectral',
#  'Spectral_r',
#  'Wistia',
#  'Wistia_r',
#  'YlGn',
#  'YlGnBu',
#  'YlGnBu_r',
#  'YlGn_r',
#  'YlOrBr',
#  'YlOrBr_r',
#  'YlOrRd',
#  'YlOrRd_r',
#  '_LUTSIZE',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_api',
#  '_auto_norm_from_scale',
#  '_colormaps',
#  '_ensure_cmap',
#  '_gen_cmap_registry',
#  'afmhot',
#  'afmhot_r',
#  'autumn',
#  'autumn_r',
#  'binary',
#  'binary_r',
#  'bone',
#  'bone_r',
#  'brg',
#  'brg_r',
#  'bwr',
#  'bwr_r',
#  'cbook',
#  'cividis',
#  'cividis_r',
#  'cmaps_listed',
#  'colors',
#  'cool',
#  'cool_r',
#  'coolwarm',
#  'coolwarm_r',
#  'copper',
#  'copper_r',
#  'cubehelix',
#  'cubehelix_r',
#  'datad',
#  'flag',
#  'flag_r',
#  'functools',
#  'get_cmap',
#  'gist_earth',
#  'gist_earth_r',
#  'gist_gray',
#  'gist_gray_r',
#  'gist_grey',
#  'gist_heat',
#  'gist_heat_r',
#  'gist_ncar',
#  'gist_ncar_r',
#  'gist_rainbow',
#  'gist_rainbow_r',
#  'gist_stern',
#  'gist_stern_r',
#  'gist_yarg',
#  'gist_yarg_r',
#  'gist_yerg',
#  'gnuplot',
#  'gnuplot2',
#  'gnuplot2_r',
#  'gnuplot_r',
#  'gray',
#  'gray_r',
#  'grey',
#  'hot',
#  'hot_r',
#  'hsv',
#  'hsv_r',
#  'inferno',
#  'inferno_r',
#  'jet',
#  'jet_r',
#  'ma',
#  'magma',
#  'magma_r',
#  'mpl',
#  'nipy_spectral',
#  'nipy_spectral_r',
#  'np',
#  'ocean',
#  'ocean_r',
#  'pink',
#  'pink_r',
#  'plasma',
#  'plasma_r',
#  'prism',
#  'prism_r',
#  'rainbow',
#  'rainbow_r',
#  'scale',
#  'seismic',
#  'seismic_r',
#  'spring',
#  'spring_r',
#  'summer',
#  'summer_r',
#  'tab10',
#  'tab10_r',
#  'tab20',
#  'tab20_r',
#  'tab20b',
#  'tab20b_r',
#  'tab20c',
#  'tab20c_r',
#  'terrain',
#  'terrain_r',
#  'turbo',
#  'turbo_r',
#  'twilight',
#  'twilight_r',
#  'twilight_shifted',
#  'twilight_shifted_r',
#  'viridis',
#  'viridis_r',
#  'winter',
#  'winter_r']

# %%
# 워드 클라우드 객체 생성
wc = WordCloud(
    font_path = fontPath[0],
    width = 800, 
    height = 800, 
    background_color = 'black', 
    colormap = 'Blues'
)

# %%
# 워드 클라우드를 시각화
plt.figure(figsize = (6, 6), dpi = 100)
wcgf = wc.generate_from_frequencies(frequencies = freq)
plt.imshow(X = wcgf)
plt.axis('off')
plt.show()

# %% [markdown]
# # 3. 연관 단어 시각화

# %%
# 단어 간 상관계수 행렬 생성
# [참고] 열(차원) 개수가 많을수록 오래 걸림
corMat = dtm.corr().round(4)

# %%
# corMat의 일부 확인
corMat.iloc[0:10, 0:10]
# Out:
#          공장      미국     배터리     보조금      생산      시대      시장      유럽     인플레  \
# 공장   1.0000  0.1108 -0.0063 -0.0607  0.0268 -0.0365 -0.0214 -0.0327 -0.0342
# 미국   0.1108  1.0000 -0.0369  0.0894  0.0534 -0.0401  0.0262 -0.0360  0.0355
# 배터리 -0.0063 -0.0369  1.0000 -0.0843 -0.0048 -0.0520  0.0575 -0.0466 -0.0197
# 보조금 -0.0607  0.0894 -0.0843  1.0000 -0.0610 -0.0742 -0.0989 -0.0215  0.1457
# 생산   0.0268  0.0534 -0.0048 -0.0610  1.0000 -0.0370 -0.0208 -0.0332 -0.0348
# 시대  -0.0365 -0.0401 -0.0520 -0.0742 -0.0370  1.0000 -0.0152 -0.0308 -0.0323
# 시장  -0.0214  0.0262  0.0575 -0.0989 -0.0208 -0.0152  1.0000  0.0948 -0.0430
# 유럽  -0.0327 -0.0360 -0.0466 -0.0215 -0.0332 -0.0308  0.0948  1.0000  0.0179
# 인플레 -0.0342  0.0355 -0.0197  0.1457 -0.0348 -0.0323 -0.0430  0.0179  1.0000
# 전기차 -0.0656 -0.0246 -0.0318 -0.0206 -0.0227  0.1737  0.0469  0.0351 -0.0198
#
#         전기차
# 공장  -0.0656
# 미국  -0.0246
# 배터리 -0.0318
# 보조금 -0.0206
# 생산  -0.0227
# 시대   0.1737
# 시장   0.0469
# 유럽   0.0351
# 인플레 -0.0198
# 전기차  1.0000

# %%
# 키워드 연관 단어로 막대 그래프를 그리는 함수 생성
def plot_assocs(keyword, n = 10, pal = 'Greys_r'):
    assocs = corMat[keyword].sort_values(ascending = False).head(n = n+1).iloc[1:]
    sns.barplot(x = assocs.index, y = assocs.values, hue = assocs.index, palette = pal)
    plt.title(label = '연관 단어 목록')
    plt.xlabel(xlabel = '고빈도 단어')
    plt.ylim(0, 1.0)
    for i, v in enumerate(assocs):
        plt.text(x = i, y = v, s = f'{v:.2f}', ha = 'center', va = 'bottom')

# %%
# 연관 단어를 반환하는 함수 테스트
plot_assocs(keyword = '보조금', pal = 'Greens_r')

# %%
# 연관 단어를 반환하는 함수 테스트
plot_assocs(keyword = '테슬라', pal = 'Greens_r')

# %%
# 연관 단어를 반환하는 함수 테스트
plot_assocs(keyword = '미국', pal = 'Greens_r')
