# %%
import pandas as pd

# %%
df = pd.read_csv('processed_data_2.csv')

# %%
df.head()
# Out:
#        번호     프로그램명  장르   채널                  날짜 요일      시작시간      종료시간  \
# 0  1313.0  고딩엄빠2(본)  오락  MBN  2022-10-11 0:00:00  화  22:22:15  23:10:33
# 1  1333.0  고딩엄빠2(본)  오락  MBN  2022-10-18 0:00:00  화  22:21:12  23:05:29
# 2  1394.0  고딩엄빠2(본)  오락  MBN  2022-10-25 0:00:00  화  22:22:28  23:07:13
# 3  1666.0  고딩엄빠2(본)  오락  MBN  2022-10-04 0:00:00  화  22:21:19  23:09:18
# 4   730.0  고딩엄빠2(본)  오락  MBN  2022-11-01 0:00:00  화  22:20:00  23:07:15
#
#        방송길이   회차  ...  40대 여자_시청시간  40대 여자_시청률  50대 남자_시청시간  50대 남자_시청률  \
# 0  48:18:00  19회  ...     0.908565    1.032460     0.351332    0.399241
# 1  44:17:00  20회  ...     0.592809    0.689313     0.450179    0.523464
# 2  41:53:00  21회  ...     0.792907    0.911387     0.254064    0.292027
# 3  47:59:00  18회  ...     0.592013    0.688388     0.738021    0.858164
# 4  47:15:00  22회  ...     0.751967    0.864330     0.506535    0.582224
#
#    50대 여자_시청시간  50대 여자_시청률  60세 이상 남자_시청시간  60세 이상 남자_시청률  60세 이상 여자_시청시간  \
# ...
